# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/Users/lizecheng/Documents/OSU Study related/Undergraduate Research/Prof. Li/Datebase/ECG/ECG-ID 90 people/P1-1.csv')
data.head()
# Out:
#    Timestamp  'ECG I'  'ECG I filtered'
# 0      0.000   -0.085            -0.115
# 1      0.002   -0.080            -0.115
# 2      0.004   -0.070            -0.120
# 3      0.006   -0.075            -0.120
# 4      0.008   -0.095            -0.120

# %%
fig,axes=plt.subplots(3,1, figsize=(12,20))

for i, ax in enumerate(axes.flatten()):
    y=data.iloc[:,1:2].values
    ax.plot(y,color=plt.cm.Paired(i/10.))
plt.savefig('/Users/lizecheng/Documents/OSU Study related/Undergraduate Research/Prof. Li/Datebase/ECG/ECG-ID 90 people.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
